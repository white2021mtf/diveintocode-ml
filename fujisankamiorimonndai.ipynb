# %% [markdown]
# 【問題1】何回折ったら富士山を超えるか
# 厚さが「富士山の高さ(3776m)」を超えるのに必要な紙を折る最小回数を計算するプログラムを作成してください。
#
# 紙を折った時の厚さの数式
# 紙を
# n
#  回折ったときの厚さを
# t
# n
#  としたとき、以下のように表せます。
#
#
# t
# n
# =
# t
# 0
# ×
# 2
# n
#
# 一般的なコピー用紙の厚さはおよそ 0.00008m なので、
# t
# 0
# =
# 0.00008
#  とします。
#  2^n=tn/t0
#  n = log2(tn/t0)
#  tn=3776m,t0=0.00008mを代入して計算すると

# %%
import math
print(math.log2(3776/0.00008))
print(math.log2(384400000/0.00008))
# Out:
# 25.49228352379865
# 42.12767356964737

# %% [markdown]
# よって、26回折ると富士山を超える

# %% [markdown]
# 【問題2】任意の厚さに対応した関数
# 高さを入力すると、それを超えるのに必要な紙を折る最小回数を出力する関数を実装してください。引数として、折る前の厚さ
# t
# 0
#  も設定できるようにしましょう。
#
#
# この関数を利用して、「最も近い太陽以外の恒星」に到達するには紙を何回折る必要があるか計算してください。
# 「最も近い太陽以外の恒星」は「プロキシマ・ケンタウリ」で、地球からの距離はおよそ
# 4.0175
# ×
# 10
# 16
# m です。

# %%
'''任意の厚さに対応した関数名：Any thickness（AnyThickness）、高さh[m]、折る最小回数N[回]とする
N = log2(tn/t0)で求まる。'''

import math
t0=0.00008
def AnyThickness(h):
  N = math.log2(h/t0)
  return N
#h=4.0175 × 10 16 m代入
h=4.0175 * (10 **16)
N = AnyThickness(h)
print(N)
# Out:
# 68.76678801653497

# %% [markdown]
# よって、「最も近い太陽以外の恒星」に到達するには紙を６９回折る必要がある。

# %% [markdown]
# 【問題3】必要な紙の長さ
# 実際のところ身近にある紙は43回はおろか10回も折れません。しかし、大きな紙ほどたくさん折ることができ、トイレットペーパーのような長い紙を一方向に折ることを考えた時の折れる回数を求める公式が存在します。
#
#
# 厚さ $t_{0}$ の紙をn回折るために必要な紙の長さLは以下の公式で求まります。
#
#
# \[L = \frac{\pi t_{0}}{6}(2^n + 4)(2^n - 1)\]
# この公式を利用して、実際に紙を折り任意の厚さに到達するために必要な紙の長さを求める関数を実装してください。
#
#
# そしてこれを使って「月」「富士山」「最も近い太陽以外の恒星」に届くために必要な紙の長さを求めてください。
# 厚さt=0.00008m
# 「月」までの距離384,400,000[m]は
# ４３回最小折る回数必要
# 「富士山」の高さ3776[m]
# ２６回最小折る回数必要
# 「最も近い太陽以外の恒星」までの距離 4.0175 × 10 ^16 m[m]６９回最小折る回数必要

# %%
import math

#厚さt0[m],N[回]折る
t0=0.00008
#必要な紙の長さL[m] 関数名：Required paper length（略してRPLとする）
def RPL(t0,N):
  #厚さ  𝑡0  の紙をn回折るために必要な紙の長さLは以下の公式より
  L = ((math.pi * (t0)) / 6) *(2 ** N + 4)*(2 ** N - 1)
  return L

#「月」までに必要な長さL1とすると、N=43回
L1 = RPL(0.00008,43)
print("L1の長さは、")
print(L1)  
print("[m]")

#「富士山」までに必要な長さL2とすると、N=26回
L2 = RPL(0.00008,26)
print("L2の長さは、")
print(L2)  
print("[m]")

#「最も近い太陽以外の恒星」までに必要な長さL1とすると、N=43回
L3 = RPL(0.00008,69)
print("L3の長さは、")
print(L3)  
print("[m]")
# Out:
# L1の長さは、
# 3.240919444170781e+21
# [m]
# L2の長さは、
# 188646348487.24017
# [m]
# L3の長さは、
# 1.4595803601100348e+37
# [m]
