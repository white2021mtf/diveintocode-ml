# %%
# 紙を1回折った時の厚さを計算するコード

THICKNESS = 0.00008
folded_thickness = THICKNESS * 2
print("厚さ： {}メートル".format(folded_thickness))
# Out:
# 厚さ： 0.00016メートル

# %% [markdown]
# 【問題1】べき乗の算術演算子を使用した実装

# %%
# 紙を43回折った時の厚さを計算するコード(べき乗の算術演算子を使用)
#t43=t0*2^43
THICKNESS = 0.00008
folded_thickness = THICKNESS * (2**43)
print("厚さ： {}メートル".format(folded_thickness))
# Out:
# 厚さ： 703687441.77664メートル

# %%
# 紙を43回折った時の厚さを計算するコード(for文を使用)
#t43=t0*2^43
THICKNESS = 0.00008
for i in range(43):
  old = THICKNESS
  THICKNESS *= 2.
  #num *= THICKNESS
print(str(old) + " * 2. = " + "厚さ： {}メートル".format(THICKNESS))
#print("厚さ： {}メートル".format(num))
# Out:
# 351843720.88832 * 2. = 厚さ： 703687441.77664メートル

# %% [markdown]
# 【問題2】単位の変換

# %%
# メートルをキロメートルに変換して小数点以下2桁で表示する
print("厚さ： {:.2f}キロメートル".format(folded_thickness / 1000))
# Out:
# 厚さ： 703687.44キロメートル

# %% [markdown]
# 月までの距離はおよそ 384,400 km です。折った紙が月に届くかどうか確認してみましょう。⇨月まで届いた。

# %% [markdown]
# 【問題3】for文を使用して作成

# %%
# 紙を43回折った時の厚さを計算するコード(for文を使用)
THICKNESS = 0.00008
for i in range(43):
  old = THICKNESS
  THICKNESS *= 2.
print(str(old) + " * 2. = " + "厚さ： {}メートル".format(THICKNESS))
# Out:
# 351843720.88832 * 2. = 厚さ： 703687441.77664メートル

# %% [markdown]
# 【問題4】計算時間の比較

# %%
import time
start = time.time()
#####
# ここに比較したいコードを貼り付ける
THICKNESS = 0.00008
folded_thickness = THICKNESS * (2**43)
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# time : 5.14984130859375e-05[s]

# %%
import time
start = time.time()
#####
# ここに比較したいコードを貼り付ける
THICKNESS = 0.00008
for i in range(43):
  old = THICKNESS
  THICKNESS *= 2.
#####
elapsed_time = time.time() - start
print("time : {}[s]".format(elapsed_time))
# Out:
# time : 9.894371032714844e-05[s]

# %% [markdown]
# １０回比較した結果、
# ７：３でべき乗の方法が計算が早かった。

# %%
# %%timeit
THICKNESS = 0.00008
for i in range(43):
  old = THICKNESS
  THICKNESS *= 2.
# Out:
# 100000 loops, best of 5: 2.1 µs per loop

# %%
# %%timeit
THICKNESS = 0.00008
folded_thickness = THICKNESS * (2**43)
# Out:
# The slowest run took 28.28 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000000 loops, best of 5: 72.7 ns per loop

# %% [markdown]
# 4.グラフによる可視化
# 【問題5】リストへの保存

# %%
# 紙を43回折った時の厚さを計算するコード(for文を使用)
THICKNESSlist = []
# THICKNESS = 0.00008
# THICKNESS = 8
# THICKNESSlist = THICKNESS
# print(THICKNESSlist)
THICKNESSlist.append(0.00008)
old = 0.00008
# THICKNESSlist.append(5.14)
# print(THICKNESSlist)
for i in range(43):
  # THICKNESSlist = THICKNESSlist.append(THICKNESS)
  # old = 0.00008
  old *= 2.
  # print(old)
  THICKNESSlist.append(old)
  print(THICKNESSlist)
  # THICKNESSlist = THICKNESSlist.append(old)
  #THICKNESSlist = THICKNESS
#print(str(old) + " * 2. = " + "厚さ： {}メートル".format(THICKNESS))
print("厚さ： {:.2f}キロメートル".format(old / 1000))
print(len(THICKNESSlist))
# Out:
# [8e-05, 0.00016]
# [8e-05, 0.00016, 0.00032]
# [8e-05, 0.00016, 0.00032, 0.00064]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768]
# [8e-05, 0.00016, 0.00032, 0.00064, 0.00128, 0.00256, 0.00512, 0.01024, 0.02048, 0.04096, 0.08192, 0.16384, 0.32768, 0.65536]
# ...

# %% [markdown]
# 【問題6】折れ線グラフの表示
# グラフの描画には Matplotlib という ライブラリ を用います。リストへ記録するコードの後ろで以下の雛形を使用してください。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# グラフを表示する。タイトルと軸ラベル名付き。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(THICKNESSlist)  # 「リスト名」のところにリストの変数名を入れる
plt.show()

# %% [markdown]
# 厚さがどのように変化しているか簡単に説明してください。
# ⇨紙を折る回数が３０後半から指数関数的に増大している。

# %% [markdown]
# 【問題7】グラフのカスタマイズ
# グラフをより見やすくカスタマイズしてみましょう。カスタマイズしたグラフを最低3種類作成してください。例えば以下のように書き換えることで、線の色を赤に変更できます。

# %%
# 赤い折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(THICKNESSlist, color='red')
plt.show()

# %%
# 軸の値を大きく表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness[m]")
plt.tick_params(labelsize=20) # 軸の値に関する設定を行う
plt.plot(THICKNESSlist)
plt.show()

# %% [markdown]
# 《カスタマイズ例》
#
#
# 線の色を青と赤以外にする。
# 線を太くする。
# 線を点線にする。
# 値のフォントサイズを変更する。

# %%
# 緑折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(THICKNESSlist, color='green')
plt.show()

# %%
import numpy as np
from scipy.stats import norm
# 線の太さを変えて折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(THICKNESSlist, color='green')
plt.plot(THICKNESSlist, color='black',  linestyle='solid', linewidth = 3.0, label='line1')
plt.show()

# %%
import numpy as np
from scipy.stats import norm
# 線の太さを変えて折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(THICKNESSlist, color='black',  linestyle='dashed',linewidth = 1.0, label='line2')

# %%
import numpy as np
from scipy.stats import norm
# 線の太さを変えて折れ線グラフを表示する。
plt.title("thickness of folded paper")
plt.xlabel("number of folds")
plt.ylabel("thickness [m]")
plt.plot(THICKNESSlist, color='black', linestyle='dashdot', linewidth = 0.5,label='line3')
